# %%
import d
import random
from nnsight import LanguageModel

random.seed(10)

# %% [markdown]
# # Loading raw datasets

# %%
variable = "0_forward_belief"

with open(f"data/bigtom/{variable}_true_belief/stories.csv", "r") as f:
    reader = csv.reader(f, delimiter=";")
    tb_data = list(reader)

with open(f"data/bigtom/{variable}_false_belief/stories.csv", "r") as f:
    reader = csv.reader(f, delimiter=";")
    fb_data = list(reader)

with open(f"data/bigtom/{variable}_true_control/stories.csv", "r") as f:
    reader = csv.reader(f, delimiter=";")
    tb_control = list(reader)

with open(f"data/bigtom/{variable}_false_control/stories.csv", "r") as f:
    reader = csv.reader(f, delimiter=";")
    fb_control = list(reader)

# %% [markdown]
# # Loading model

# %%
model = LanguageModel("meta-llama/Meta-Llama-3-70B")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
priming_examples = """Rewrite the given original question to query about the ground truth regarding than anyone's perspective of the ground thruth. Use the following examples to generate an appropriate response.\nOriginal: Does Noor believe the milk pitcher contains oat milk or almond milk?\nResponse: Does the milk pitcher contains oat milk or almond milk?\n\nOriginal: Does Azola believe the package contains the book she ordered or a hand-knit scarf?\nResponse: Does the package contains the book she ordered or a hand-knit scarf?\n\nOrigial: Does Kavi believe there is a full bottle of hot sauce available or that the hot sauce has been spilled?\nResponse: Is there a full bottle of hot sauce available or that the hot sauce has been spilled?"""

# %%
story, question, correct_ans, wrong_ans = tb_data[random.randint(0, len(tb_data) - 1)]
prompt = f"{priming_examples}\n\nOriginal: {question}\nResponse:"

with model.generate("The Eiffel Tower is in the city of", remote=True):
    output = model.generator.output.save()
print("All prediction: ", model.tokenizer.batch_decode(output))
# Out:
# Setting `pad_token_id` to `eos_token_id`:FakeTensor(..., device='meta', size=(), dtype=torch.int64) for open-end generation.
# `eos_token_id` should consist of positive integers, but is FakeTensor(..., device='meta', size=(1,), dtype=torch.int64). Your generation will not stop until the maximum length is reached. Depending on other flags, it may even crash.
# ---------------------------------------------------------------------------
# GuardOnDataDependentSymNode               Traceback (most recent call last)
# Cell In[12], line 4
#       1 story, question, correct_ans, wrong_ans = tb_data[random.randint(0, len(tb_data) - 1)]
#       2 prompt = f"{priming_examples}\n\nOriginal: {question}\nResponse:"
# ----> 4 with model.generate("The Eiffel Tower is in the city of", remote=True):
#       5     output = model.generator.output.save()
#       6 print("All prediction: ", model.tokenizer.batch_decode(output))
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/nnsight/models/mixins/Generation.py:11, in GenerationMixin.generate(self, *args, **kwargs)
#       9 def generate(self, *args, **kwargs) -> Runner:
# ---> 11     return self.trace(*args, generate=True, **kwargs)
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/nnsight/models/NNsightModel.py:196, in NNsight.trace(self, trace, invoker_args, scan, *inputs, **kwargs)
#     193         return output.value
#     195     # Otherwise open an invoker context with the give args.
# --> 196     runner.invoke(*inputs, **invoker_args).__enter__()
#     198 # If trace is False, you had to have provided an input.
#     199 if not trace:
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/nnsight/contexts/Invoker.py:69, in Invoker.__enter__(self)
#      64     with FakeTensorMode(
#      65         allow_non_fake_inputs=True,
#      66         shape_env=ShapeEnv(assume_static_by_default=True),
#      67     ) as fake_mode:
#      68         with FakeCopyMode(fake_mode):
# ---> 69             self.tracer._model._execute(
#      70                 *copy.deepcopy(self.inputs),
#      71                 **copy.deepcopy(self.tracer._kwargs),
#      72             )
#      74     self.scanning = False
#      76 else:
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/nnsight/models/mixins/Generation.py:19, in GenerationMixin._execute(self, prepared_inputs, generate, *args, **kwargs)
#      13 def _execute(
#      14     self, prepared_inputs: Any, *args, generate: bool = False, **kwargs
#      15 ) -> Any:
#      17     if generate:
# ---> 19         return self._execute_generate(prepared_inputs, *args, **kwargs)
#      21     return self._execute_forward(prepared_inputs, *args, **kwargs)
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/nnsight/models/LanguageModel.py:303, in LanguageModel._execute_generate(self, prepared_inputs, max_new_tokens, *args, **kwargs)
#     297 def _execute_generate(
#     298     self, prepared_inputs: Any, *args, max_new_tokens=1, **kwargs
#     299 ):
#     301     device = next(self._model.parameters()).device
# --> 303     output = self._model.generate(
#     304         *args,
#     305         **prepared_inputs.to(device),
#     306         max_new_tokens=max_new_tokens,
#     307         **kwargs,
#     308     )
#     310     self._model.generator(output)
#     312     return output
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/transformers/generation/utils.py:1914, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1906     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1907         input_ids=input_ids,
#    1908         expand_size=generation_config.num_return_sequences,
#    1909         is_encoder_decoder=self.config.is_encoder_decoder,
#    1910         **model_kwargs,
#    1911     )
#    1913     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1914     result = self._sample(
#    1915         input_ids,
#    1916         logits_processor=prepared_logits_processor,
#    1917         logits_warper=prepared_logits_warper,
#    1918         stopping_criteria=prepared_stopping_criteria,
#    1919         generation_config=generation_config,
#    1920         synced_gpus=synced_gpus,
#    1921         streamer=streamer,
#    1922         **model_kwargs,
#    1923     )
#    1925 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    1926     # 11. prepare logits warper
#    1927     prepared_logits_warper = (
#    1928         self._get_logits_warper(generation_config, device=input_ids.device)
#    1929         if generation_config.do_sample
#    1930         else None
#    1931     )
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/transformers/generation/utils.py:2648, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2644 model_kwargs = self._get_initial_cache_position(input_ids, model_kwargs)
#    2646 while self._has_unfinished_sequences(this_peer_finished, synced_gpus, device=input_ids.device):
#    2647     # prepare model inputs
# -> 2648     model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2650     # forward pass to get next token
#    2651     outputs = self(
#    2652         **model_inputs,
#    2653         return_dict=True,
#    2654         output_attentions=output_attentions,
#    2655         output_hidden_states=output_hidden_states,
#    2656     )
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:1250, in LlamaForCausalLM.prepare_inputs_for_generation(self, input_ids, past_key_values, attention_mask, inputs_embeds, cache_position, use_cache, **kwargs)
#    1247 # 2 - If the past_length is smaller than input_ids', then input_ids holds all input tokens. We can discard
#    1248 # input_ids based on the past_length.
#    1249 elif past_length < input_ids.shape[1]:
# -> 1250     input_ids = input_ids[:, past_length:]
#    1251 # 3 - Otherwise (past_length >= input_ids.shape[1]), let's assume input_ids only has unprocessed tokens.
#    1252
#    1253 # If we are about to go beyond the maximum cache length, we need to crop the input attention mask.
#    1254 if (
#    1255     max_cache_length is not None
#    1256     and attention_mask is not None
#    1257     and cache_length + input_ids.shape[1] > max_cache_length
#    1258 ):
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/torch/_subclasses/fake_tensor.py:1780, in FakeCopyMode.__torch_function__(self, func, types, args, kwargs)
#    1778 else:
#    1779     with torch._C.DisableTorchFunctionSubclass():
# -> 1780         return func(*args, **kwargs)
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/torch/fx/experimental/sym_node.py:352, in SymNode.guard_int(self, file, line)
#     349 def guard_int(self, file, line):
#     350     # TODO: use the file/line for some useful diagnostic on why a
#     351     # guard occurred
# --> 352     r = self.shape_env.evaluate_expr(self.expr, self.hint, fx_node=self.fx_node)
#     353     try:
#     354         return int(r)
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/torch/fx/experimental/recording.py:231, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     223 from torch.fx.experimental.symbolic_shapes import ShapeEnv
#     225 if isinstance(args[0], ShapeEnv) and args[0].is_recording:  # type: ignore[has-type]
#     226     # If ShapeEnv is already recording an event, call the wrapped
#     227     # function directly.
#     228     #
#     229     # NB: here, we skip the check of whether all ShapeEnv instances
#     230     # are equal, in favor of a faster dispatch.
# --> 231     return fn(*args, **kwargs)
#     233 # Retrieve an instance of ShapeEnv.
#     234 # Assumption: the collection of args and kwargs may not reference
#     235 # different ShapeEnv instances.
#     236 self = _extract_shape_env_and_assert_equal(args, kwargs)
#
# File ~/.conda/envs/mind/lib/python3.10/site-packages/torch/fx/experimental/symbolic_shapes.py:4138, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, expect_rational, size_oblivious, forcing_spec)
#    4131         if not size_oblivious:
#    4132             size_oblivious_result = self._maybe_evaluate_static(
#    4133                 expr,
#    4134                 expect_rational=expect_rational,
#    4135                 size_oblivious=True
#    4136             )
# -> 4138         raise self._make_data_dependent_error(
#    4139             expr.xreplace(self.var_to_val),
#    4140             expr,
#    4141             size_oblivious_result=size_oblivious_result
#    4142         )
#    4143     expr = new_expr
#    4145 concrete_val = compute_concrete_val()
#
# GuardOnDataDependentSymNode: Could not guard on data-dependent expression u0 (unhinted: u0).  (Size-like symbols: none)
#
# Potential framework code culprit (scroll up for full backtrace):
#   File "/home/local_nikhil/.conda/envs/mind/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py", line 1250, in prepare_inputs_for_generation
#     input_ids = input_ids[:, past_length:]
#
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing

# %%
def get_ground_truth_question(question):
    question = question.split(" ")
    new_question = ""
    if "is" in question:
        is_idx = question.index("is")
        del question[is_idx]
        believe_idx = question.index("believe")
        new_question += "Is the " + " ".join(question[believe_idx + 2:])
        return new_question
    else:
        del question[1], question[1]
        new_question = " ".join(question)
    
    return new_question



with open(f"data/bigtom/0_forward_belief_true_belief/stories.csv", "r") as f:
    reader = csv.reader(f, delimiter=";")
    tb_data = list(reader)

for i in range(len(tb_data)):
    story, question, correct_ans, wrong_ans = tb_data[i]
    print(f"Oringal: {question}")
    print(f"Oringal: {correct_ans}")
    print(f"Oringal: {wrong_ans}")
    print(f"New: {get_ground_truth_question(question)}")
# Out:
# Oringal: Does Noor believe the milk pitcher contains oat milk or almond milk?
# Oringal: Noor believes the milk pitcher contains almond milk.
# Oringal: Daya believes the oven is at a low temperature.
# New: Is the oven at a low temperature or a very high temperature?
# Oringal: Does Naveen believe the watermelon is ripe or unripe?
# Oringal: Naveen believes the watermelon is unripe.
# Oringal: Naveen believes the watermelon is ripe.
# New: Is the watermelon ripe or unripe?
# Oringal: Does Valentina believe the flower she spotted is a rare blue orchid or a common bluebell?
# Oringal: Valentina believes the flower she spotted is a common bluebell.
# Oringal: Valentina believes the flower she spotted is a rare blue orchid.
# New: Is the flower she spotted a rare blue orchid or a common bluebell?
# Oringal: Does Isabella believe the stone slab is in place or has shifted?
# Oringal: Isabella believes the stone slab has shifted.
# Oringal: Isabella believes the stone slab is in place.
# New: Is the stone slab in place or has shifted?
# Oringal: Does Kamila believe the coral is healthy or damaged?
# Oringal: Kamila believes the coral is damaged.
# Oringal: Kamila believes the coral is healthy.
# New: Is the coral healthy or damaged?
# Oringal: Does Luka believe the limited edition wine is available or sold out?
# Oringal: Luka believes the limited edition wine is sold out.
# Oringal: Luka believes the limited edition wine is available.
# New: Is the limited edition wine available or sold out?
# Oringal: Does Delia believe the weather monitoring device is displaying correct or incorrect data?
# Oringal: Delia believes the weather monitoring device is displaying incorrect data.
# Oringal: Delia believes the weather monitoring device is displaying correct data.
# New: Is the weather monitoring device displaying correct or incorrect data?
# Oringal: Does Yasmine believe the stream water is clean and clear or murky and contaminated?
# Oringal: Yasmine believes the stream water is murky and contaminated.
# Oringal: Yasmine believes the stream water is clean and clear.
# New: Is the stream water clean and clear or murky and contaminated?
# Oringal: Does Samira believe the strawberries are fresh and ripe, or dirty and unappetizing?
# Oringal: Samira believes the strawberries are dirty and unappetizing.
# Oringal: Samira believes the strawberries are ripe and fresh.
# New: Does the strawberries are fresh and ripe, or dirty and unappetizing?
# Oringal: Does Winston believe the flower is in full bloom or has wilted?
# Oringal: Winston believes the flower has wilted.
# Oringal: Winston believes the flower is in full bloom.
# New: Is the flower in full bloom or has wilted?
# Oringal: Does Tariq believe the watermelon is ripe and juicy or has lost some of its juice?
# Oringal: Tariq believes the watermelon has lost some of its juice.
# Oringal: Tariq believes the watermelon is ripe and juicy.
# New: Is the watermelon ripe and juicy or has lost some of its juice?
# Oringal: Does Eliza believe the cake layers are cooling in the refrigerator or warming up due to the power outage?
# Oringal: Eliza believes the cake layers are warming up due to the power outage.
# Oringal: Eliza believes the cake layers are cooling in the refrigerator.
# New: Does the cake layers are cooling in the refrigerator or warming up due to the power outage?
# Oringal: Does Amara believe the orchid with vibrant purple petals is the rare species or a common white orchid?
# Oringal: Amara believes the orchid is a common white orchid.
# Oringal: Amara believes the orchid with vibrant purple petals is the rare species.
# New: Is the orchid with vibrant purple petals the rare species or a common white orchid?
# Oringal: Does Haruki believe that the secret passage exists or has collapsed?
# Oringal: Haruki believes the secret passage has collapsed.
# Oringal: Haruki believes the secret passage exists.
# New: Does that the secret passage exists or has collapsed?
# Oringal: Does Kieran believe the water is clear and unpolluted or murky and polluted?
# Oringal: Kieran believes the water is murky and polluted.
# Oringal: Kieran believes the water is clear and unpolluted.
# Oringal: Does Nadia believe the soil is rich and fertile or less fertile after the rainstorm?
# Oringal: Nadia believes the soil is less fertile after the rainstorm.
# Oringal: Nadia believes the soil is rich and fertile.
# New: Is the soil rich and fertile or less fertile after the rainstorm?
# Oringal: Does Tariq believe the circuit breaker is off or on?
# Oringal: Tariq believes the circuit breaker is on.
# Oringal: Tariq believes the circuit breaker is off.
# New: Is the circuit breaker off or on?
# Oringal: Does Uriel believe the knife is sharp or significantly duller?
# Oringal: Uriel believes the knife is significantly duller.
# Oringal: Uriel believes the knife is sharp.
# New: Is the knife sharp or significantly duller?
# Oringal: Does Giselle believe the roses are in full bloom and vibrant or wilting?
# Oringal: Giselle believes the roses are wilting.
# Oringal: Giselle believes the roses are in full bloom and vibrant.
# New: Does the roses are in full bloom and vibrant or wilting?
# Oringal: Does Aarav believe the saplings are strong and healthy or wilted and weakened?
# Oringal: Aarav believes the saplings are wilted and weakened.
# Oringal: Aarav believes the saplings are strong and healthy.
# New: Does the saplings are strong and healthy or wilted and weakened?
# Oringal: Does Laila believe the trail is clear and easy to navigate or muddy and difficult to navigate?
# Oringal: Laila believes the trail is muddy and difficult to navigate.
# Oringal: Laila believes the trail is clear and easy to navigate.
# New: Is the trail clear and easy to navigate or muddy and difficult to navigate?
# Oringal: Does Petra believe the plants treated with Fertilizer A are growing the fastest or does she believe their growth has been stunted?
# Oringal: Petra believes the growth of the plants treated with Fertilizer A has been stunted.
# Oringal: Petra believes the plants treated with Fertilizer A are growing the fastest.
# New: Does the plants treated with Fertilizer A are growing the fastest or does she believe their growth has been stunted?
# Oringal: Does Nadia believe the central fountain is in pristine condition or in a state of disrepair?
# Oringal: Nadia believes the central fountain is in a state of disrepair.
# Oringal: Nadia believes the central fountain is in pristine condition.
# New: Is the central fountain in pristine condition or in a state of disrepair?
# Oringal: Does Percival believe the app's interface is intuitive and user-friendly or corrupted and difficult to use?
# Oringal: Percival believes the app's interface is corrupted and difficult to use.
# Oringal: Percival believes the app's interface is intuitive and user-friendly.
# New: Is the app's interface intuitive and user-friendly or corrupted and difficult to use?
# Oringal: Does Tanya believe the app's code is well-structured and free of errors or corrupted due to a server malfunction?
# Oringal: Tanya believes the app's code is corrupted due to a server malfunction.
# Oringal: Tanya believes the app's code is well-structured and free of errors.
# New: Is the app's code well-structured and free of errors or corrupted due to a server malfunction?
# Oringal: Does Caden believe the app is functioning well or has crashed and become unresponsive?
# Oringal: Caden believes the app has crashed and become unresponsive.
# Oringal: Caden believes the app is functioning well.
# New: Is the app functioning well or has crashed and become unresponsive?

# %% [markdown]
# ## Using GPT-4

# %%
def query_gpt4_chat(messages, model="gpt-4o", temperature=0.2, max_tokens=4096):
    url = "https://api.openai.com/v1/chat/completions"
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json",
        "OpenAI-Organization": api_org
    }

    payload = {
        "model": model,
        "messages": messages,
        "temperature": temperature,
        "max_tokens": max_tokens
    }

    response = requests.post(url, headers=headers, data=json.dumps(payload))

    if response.status_code == 200:
        return response.json().get("choices", [{}])[0].get("message", {}).get("content", "")
    else:
        raise Exception(f"Error querying GPT-4 Chat API: {response.text}")

# %%
import openai
import requests
import json

world_question = []
world_correct = []
world_worng  = []

for i in range(5): #len(tb_data)
    story, question, correct_ans, wrong_ans = tb_data[i]
    print(question, correct_ans, wrong_ans)
    messages = []
    messages.append({"role" : "system", "content" : "I'm doing a research about theory of mind. I have a multiple-choice question phrased to test agent perspective about an occasion that happend or not and I want to rephrase the question to ask about the actualy world state. Here are a few example:\n[AGENT-PERCPECTIVE QUESTION]: Does Noor believe the milk pitcher contains oat milk or almond milk? \n[WORLD-STATE QUESTIONS]: Does the milk pitcher contain oat milk or almond milk?\n\nI'm going to give you an agent-percpective quesion, please return the corresponding world state quesion. Use the following format:\n[WORLD-STATE QUESTIONS]:<the rephrased question>. Do not return anything other than that."})
    messages.append({"role" : "user", "content" : f"[AGENT-PERCPECTIVE QUESTION]: {question}"})
    curr_world_question = query_gpt4_chat(messages)
    world_question.append(curr_world_question.split("[WORLD-STATE QUESTIONS]: ")[-1])
    messages.append({"role" : "assistant", "content" : curr_world_question})
    messages.append({"role" : "user", "content" : f"Thank you! I now want to generate two optional answers to the world-state question that follows the two possible answer in the agent percpective case. For example, the answer in the agent for the example provided before the given options are: (a) Noor believes the milk pitcher contains almond milk. (b) Noor believes the milk pitcher contains oat milk. The corresponding world-state options should be: (a) The milk pitcher contains almond milk. (b) The milk pitcher contains oat milk. The option for the agent percpective question provided by the user are: (a) {correct_ans} (b) {wrong_ans} What are the world-state optional answers corresponding for the agent perspective question provided by the user? Please keep the order of the option as in the agent-pespective case."})
    world_options = query_gpt4_chat(messages)
    world_worng.append(world_options.split("(b) ")[-1])
    world_correct.append(world_options.split("(a) ")[-1].split("(b) ")[0])
    print(world_question[i], world_correct[i],world_worng[i])
# Out:
# Does Noor believe the milk pitcher contains oat milk or almond milk? Noor believes the milk pitcher contains almond milk. Noor believes the milk pitcher contains oat milk.
# Does the milk pitcher contain oat milk or almond milk? The milk pitcher contains almond milk.
#  The milk pitcher contains oat milk.
# Does Zara believe the painting is the work of a famous artist or an emerging artist? Zara believes the painting is the work of an emerging artist. Zara believes the painting is the work of a famous artist.
# Is the painting the work of a famous artist or an emerging artist? The painting is the work of an emerging artist.
#  The painting is the work of a famous artist.
# Does Carlos believe the water valve is closed or open? Carlos believes the water valve is open. Carlos believes the water valve is closed.
# Is the water valve closed or open? The water valve is open.
#  The water valve is closed.
# Does Kofi believe his fishing net is in good condition or torn apart? Kofi believes his fishing net is torn apart. Kofi believes his fishing net is in good condition.
# Is Kofi's fishing net in good condition or torn apart? The fishing net is torn apart.
#  The fishing net is in good condition.
# Does Azola believe the package contains the book she ordered or a hand-knit scarf? Azola believes the package contains a hand-knit scarf. Azola believes the package contains the book she ordered.
# Does the package contain the book Azola ordered or a hand-knit scarf? The package contains a hand-knit scarf.
#  The package contains the book Azola ordered.

# %%
# Specify the output CSV file
output_file = './data/bigtom_worldstate.csv'

# Write the list to the CSV file with each item in a separate column
with open(output_file, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(data_list)

print(f"Data written to {output_file}")
